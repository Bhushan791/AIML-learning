# %%
import json

def find_pages_you_might_like(user_id, data):
    user_pages = {}  # correct variable name

    for user in data['users']:
        user_pages[user['id']] = set(user['liked_pages'])

    if user_id not in user_pages:
        return []

    user_liked_pages = user_pages[user_id]

    page_suggestions = {}

    for other_user, other_user_pages in user_pages.items():
        if other_user != user_id:
            shared_pages = user_liked_pages.intersection(other_user_pages)

            for page in other_user_pages:
                if page not in user_liked_pages:
                    
                    page_suggestions[page] = page_suggestions.get(page, 0) + len(shared_pages)

    sorted_pages = sorted(page_suggestions.items(), key=lambda x: x[1], reverse=True)
    return [(page_id, score)  for page_id, score in sorted_pages if score>0]






def load_data(filename):
    with open (filename,  "r") as file:
        return json.load(file)


data = load_data("massive_data.json")
user_id= 5
page_recc= find_pages_you_might_like(user_id, data)

    
print(page_recc)
# Out:
# [(101, 1), (103, 1), (111, 1)]
