# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#               ACTOR                      FILM  YEAR            GENRE  \
# 0    Shah Rukh Khan           Chennai Express  2013    Action/Comedy
# 1       Salman Khan         Bajrangi Bhaijaan  2015     Drama/Action
# 2        Aamir Khan                    Dangal  2016     Sports/Drama
# 3  Deepika Padukone                      Piku  2015     Comedy/Drama
# 4     Ranveer Singh                 Gully Boy  2019    Musical/Drama
# 5      Katrina Kaif  Zindagi Na Milegi Dobara  2011  Adventure/Drama
# 6    Hrithik Roshan                       War  2019  Action/Thriller
# 7        Alia Bhatt                     Raazi  2018   Thriller/Drama
# 8     Ranbir Kapoor                     Sanju  2018  Biography/Drama
# 9    Kangana Ranaut                     Queen  2014     Comedy/Drama
#
#    BOXOFFICE  IMDB
# 0        423   6.1
# 1        969   8.0
# 2       2027   8.4
# 3        140   7.6
# 4        238   8.0
# 5        377   8.1
# 6        475   6.5
# 7        220   7.8
# 8        586   7.7
# ...

# %%
df = df[df['IMDB']>8.0]
df
# Out:
#             ACTOR                      FILM  YEAR            GENRE  BOXOFFICE  \
# 2      Aamir Khan                    Dangal  2016     Sports/Drama       2027
# 5    Katrina Kaif  Zindagi Na Milegi Dobara  2011  Adventure/Drama        377
# 9  Kangana Ranaut                     Queen  2014     Comedy/Drama        137
#
#    IMDB
# 2   8.4
# 5   8.1
# 9   8.2

# %%
df.to_csv("data_updated.csv")   ##if you dont want indexing do --> index= False

# %% [markdown]
# we can DO with json data as well for thatif json is nested then we jave to normalise that fist... -->>see notes for that
