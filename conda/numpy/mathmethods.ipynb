# %%
import numpy as np

# %%
arr= np.array([1,2,3,4,5,6,5,6,7,5,6,4,4,5,6,7])
np.min(arr)   ##min
np.max(arr)   ##max
np.mean(arr)   ##avg(sum/num of elements)
np.std(arr)     ##standard devaiation
# Out:
# 1.6393596310755

# %%
np.sum(arr)
np.prod(arr)

np.percentile(arr, 39)
# Out:
# 3.34

# %%
np.argmin(arr)
np.argmax(arr)
# Out:
# 6

# %%
np.unique(arr)
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
a= np.array([1,2,3,4,5,6,5,6,7,5,6,4,4,5,6,7])
np.cumsum(a)
# Out:
# array([ 1,  3,  6, 10, 15, 21, 26, 32, 39, 44, 50, 54, 58, 63, 69, 76])
